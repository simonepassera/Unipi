# %% [markdown]
# <h1><center> WebScraping </h1>
# <h1><center> Anno Accademico 2022-2023 </h1>
# <h1><center>  Docente: Laura Ricci </h1>
# <h1><center>  Lezione 5 </h1>
# <h1><center>    Pandas: Introduzione</h1>
# <h1><center> 7 Febbraio 2023 </h1>

# %% [markdown]
# # Pandas
#
# * libreria utilizzata per caricare, manipolare e visualizzare dati sequenziali e in forma di tabella, come serie temporali o fogli csv
#
# * caratteristiche principali
#     * caricare e salvare dati in formati tabulari "standard"
#         * CSV (Comma-separated Values)
#         * TSV (Tab-seprated values)
#         * File Excel
#         * Formati database
#         *...
#     * indicizzazione e aggregazione flessibile di serie e di tabelle
#     * operazioni numeriche e statistiche efficienti
#     * visualizzaione facile e immediata
# * costruita su NumPy

# %% [markdown]
# # Pandas: Tipi di dato
# * due tipi di dati principali
#     * le **series** rappresentano dati *1D*, come sequenze temporali, ...
#     i i **Data Frame** reppresentano dati *2D* come un file csv, una tabella di un database, ...
# * quale è la relazione tra i due?
#     * ogni colonna di un *DataFrame* è una *Series*
# * lavoreremo con entrambe le strutture esaminando un data-set reale

# %% [markdown]
# # Pandas: lavorare con i file
# * dove stanno i miei file?

# %%
import os
print(os.getcwd())
print()
print(os.listdir(os.getcwd()))
# Out:
# C:\Users\ricci\Dropbox\My_Drop_Home\Didattica\WebScraping\Notebook\Notebook_e_slides\Notebook070223
#
# ['.ipynb_checkpoints', 'ALL_COMBINED', 'Lezione_070223.ipynb']

# %%
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

sb.pairplot(data, hue="species")

# %%
plt.plot(data.sepal_length,data.sepal_width,ls='',marker='*',color='blue')

# %%
import seaborn as sns 
sns.jointplot(x='sepal_length',y='sepal_width',data=data,height=4)

# %%
#correlation 
sns.pairplot(data,hue='class',height=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\ricci\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\users\ricci\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\users\ricci\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# ...

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
dataframe = pd.read_csv("IrisDataSet.csv")
print(dataframe)
scatter_matrix(dataframe[dataframe.species == "virginica"])
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Dove stanno i miei file?

# %%
import numpy as np 
import pandas as pd 

import os

print("file del")
for dirname, _, filenames in os.walk('ALL_COMBINED/Dataset'):
    for filename in filenames:
        print("laura")
        print(os.path.join(dirname, filename))
# Out:
# laura
# laura
# ALL_COMBINED/Dataset\ALL_COMBINED.csv
